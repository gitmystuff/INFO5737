# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/INFO5737/blob/main/Encryption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Encryption
#
# Your Name

# %% [markdown]
# ## Getting Started
#
# * Colab - get notebook from gitmystuff INFO5737 repository
# * Save a Copy in Drive
# * Remove Copy of
# * Edit your name
# * Attendance
# * Clean up Colab Notebooks folder
# * Submit shared link

# %% [markdown]
# # Ceasar's Cipher
#
# **Understanding the Caesar Cipher**
#
# The Caesar Cipher is a simple substitution cipher where each letter in the plaintext is shifted a certain number of places down the alphabet.  For example, with a shift of 3, 'A' becomes 'D', 'B' becomes 'E', and so on.
#
# The Caesar Cipher is one of the simplest and oldest encryption techniques known. It's a type of substitution cipher where each letter in the plaintext is 'shifted' a certain number of places down the alphabet.
#
# **How it works:**
#
# Imagine you want to encrypt the message "HELLO" with a shift of 3.  You would shift each letter 3 places to the right:
#
# * H -> K
# * E -> H
# * L -> O
# * L -> O
# * O -> R
#
# So, "HELLO" becomes "KHOOR".
#
# To decrypt, you simply shift the letters back by the same number of places.
#
# **Who used it?**
#
# The Caesar Cipher is named after Julius Caesar, who, according to historical accounts, used it to protect military communications.  Suetonius, a Roman historian, describes Caesar's use of a cipher with a shift of 3 in his book "Lives of the Caesars".
#
# **Security**
#
# The Caesar Cipher is very easy to break by modern standards.  There are only 25 possible keys (shifts), so an attacker could easily try all of them to decrypt the message. Frequency analysis (looking at the frequency of letters in the ciphertext) can also be used to quickly crack the code.
#
# **Significance**
#
# Despite its weakness, the Caesar Cipher is important because:
#
# * **Historical Significance:** It's one of the earliest known examples of encryption, giving us insight into the history of cryptography.
# * **Educational Value:** It's a simple and easy-to-understand cipher, making it a great introduction to the concepts of encryption and decryption.
# * **Foundation for More Complex Ciphers:** It serves as a building block for understanding more complex substitution ciphers and other encryption techniques.
#
# So, while not suitable for protecting sensitive information today, the Caesar Cipher remains an important part of the history of cryptography and a valuable tool for teaching about encryption.

# %%
# # Here's a basic Python function to implement the Caesar Cipher:

# def caesar_cipher(text, shift):
#     result = ''
#     for char in text:
#         if char.isalpha():
#             start = ord('a') if char.islower() else ord('A')
#             shifted_char = chr((ord(char) - start + shift) % 26 + start)
#         elif char.isdigit():  # Add handling for numbers
#             shifted_char = str((int(char) + shift) % 10)
#         else:
#             shifted_char = char  # Keep non-alphanumeric characters unchanged
#         result += shifted_char
#     return result

# %%
# Example Usage

# %% [markdown]
# ## Keys
#
# In encryption, keys are like the secret codes that lock and unlock your information. They are essential for scrambling (encrypting) data to keep it confidential and then unscrambling (decrypting) it to access the original information.
#
# Here's a breakdown of keys in encryption:
#
# **Types of Keys**
#
# * **Symmetric Keys:**
#     * **One Key:** In symmetric encryption, the same key is used for both encryption and decryption. It's like using the same key to lock and unlock a door.
#     * **Examples:** AES, DES, 3DES
#     * **Challenge:** Securely sharing the key between the sender and receiver.
#
# * **Asymmetric Keys:**
#     * **Two Keys:** In asymmetric encryption (public-key cryptography), there are two keys: a public key and a private key.
#     * **Public Key:** Can be shared with anyone.
#     * **Private Key:**  Kept secret by the owner.
#     * **How it Works:**  You encrypt a message with the recipient's public key, and only the recipient can decrypt it with their private key.
#     * **Examples:** RSA, ECC
#     * **Benefits:** Solves the key distribution problem of symmetric encryption.
#
# **Key Length**
#
# * **Longer is Stronger:** Key length is measured in bits (e.g., 128 bits, 256 bits). Generally, longer keys provide stronger security because they make it harder for attackers to guess the key.
# * **Balancing Act:**  Longer keys also require more computational power, so there's a trade-off between security and efficiency.
#
# **Key Management**
#
# * **Critical for Security:**  Proper key management is crucial for the overall security of an encryption system. This includes:
#     * **Secure Generation:** Generating strong, random keys.
#     * **Secure Storage:** Storing keys in a safe and protected manner.
#     * **Secure Distribution:**  Sharing keys with authorized parties in a secure way.
#     * **Key Rotation:**  Periodically changing keys to limit the impact of a compromised key.
#
# **Key Concepts**
#
# * **Confidentiality:** Keys ensure that only authorized parties with the correct key can access the encrypted data.
# * **Integrity:** Keys help ensure that the data has not been tampered with during transmission or storage.
# * **Authentication:** Asymmetric keys can be used for authentication, verifying the identity of the sender of a message.
#
# **In Summary**
#
# Keys are the foundation of encryption. They provide the necessary secrecy and control to protect sensitive information from unauthorized access. Understanding the different types of keys, their properties, and how they are managed is essential for anyone working with encryption technologies.

# %% [markdown]
# ## Symmetric Encryption
#
# **What is Symmetric Encryption?**
#
# Symmetric encryption is a type of encryption where the same key is used for both encrypting and decrypting information.  Think of it like a physical key to a lock – you use the same key to lock and unlock the door.
#
# **How it Works**
#
# 1. **Plaintext:**  The original message or data you want to protect.
# 2. **Encryption Algorithm:** A set of mathematical operations that scramble the plaintext using the key, turning it into ciphertext.
# 3. **Key:** The secret piece of information that determines how the encryption algorithm scrambles the plaintext.
# 4. **Ciphertext:** The encrypted, unreadable version of the plaintext.
# 5. **Decryption Algorithm:** The reverse of the encryption algorithm, using the same key to unscramble the ciphertext back into the original plaintext.
#
# **A Place in History**
#
# Symmetric encryption has roots that stretch back to ancient times:
#
# * **Ancient Ciphers:**  Simple substitution ciphers like the Caesar cipher (which we discussed earlier) are examples of early symmetric encryption.  These were used by Julius Caesar and other historical figures to protect military and political communications.
# * **Scytale:** Ancient Greeks used a tool called a scytale, a rod around which a strip of parchment was wrapped.  A message written on the wrapped parchment would be scrambled when unwrapped, and only someone with an identical rod could decipher it.
# * **Medieval Era:**  More complex ciphers like the Vigenère cipher were developed in the medieval era, offering increased security compared to earlier methods.
# * **World War II:** The Enigma machine, used by the Germans in World War II, is a famous example of a complex mechanical symmetric encryption device.  Breaking the Enigma code was a crucial turning point in the war.
# * **Modern Era:** With the rise of computers, symmetric encryption algorithms became much more sophisticated.  The Data Encryption Standard (DES) and the Advanced Encryption Standard (AES) are widely used examples of modern symmetric encryption algorithms.
#
# **Importance and Use Cases**
#
# Symmetric encryption remains a cornerstone of modern cryptography due to its:
#
# * **Speed and Efficiency:** It's generally faster and less computationally intensive than asymmetric encryption, making it suitable for encrypting large amounts of data.
# * **Confidentiality:** It protects the secrecy of data, ensuring that only those with the key can access the information.
#
# **Common Use Cases:**
#
# * **Data at Rest:** Encrypting files stored on hard drives or in databases.
# * **Data in Transit:**  Securing communication channels like HTTPS websites and VPNs.
# * **Password Storage:**  Hashing passwords with a salt to protect them from unauthorized access.
#
# **Challenges**
#
# * **Key Distribution:**  Securely sharing the secret key between the sender and receiver is a major challenge.
# * **Key Management:**  Managing and storing a large number of keys can become complex, especially in large systems.
#
# **Relationship to Asymmetric Encryption**
#
# While symmetric encryption is efficient, it faces the challenge of key distribution.  This is where asymmetric encryption comes in.  Asymmetric encryption uses separate keys for encryption and decryption, making it easier to share keys publicly.  Often, symmetric encryption is used for encrypting the bulk of the data, while asymmetric encryption is used to securely exchange the symmetric key.
#
# Symmetric encryption has a long and fascinating history, and it continues to play a vital role in protecting information in the digital age.
#
# **Key Concepts:**
#
# * **Symmetric Encryption:** Emphasize that the same key is used for both encryption and decryption.
# * **Key Management:** Discuss the critical importance of secure key storage and distribution.
# * **AES:** Explain that Fernet uses the Advanced Encryption Standard (AES), a widely used and robust symmetric encryption algorithm.
# * **CBC Mode:** Briefly touch upon the Cipher Block Chaining (CBC) mode of operation and its advantages in enhancing security.

# %%
# pip install cryptography

# %%
# from cryptography.fernet import Fernet

# def generate_key():
#     """
#     Generates a new encryption key.
#     """
#     key = Fernet.generate_key()
#     return key

# def encrypt_message(message, key):
#     """
#     Encrypts a message using the provided key.
#     """
#     f = Fernet(key)
#     encrypted_message = f.encrypt(message.encode())
#     return encrypted_message

# def decrypt_message(encrypted_message, key):
#     """
#     Decrypts an encrypted message using the provided key.
#     """
#     f = Fernet(key)
#     decrypted_message = f.decrypt(encrypted_message).decode()
#     return decrypted_message

# %%
# Example usage:

# %% [markdown]
# ## Symmetric-Key Block Cipher
#
# A symmetric-key block cipher is a type of encryption algorithm that encrypts data in fixed-size blocks using a single secret key for both encryption and decryption.
#
# Here's a breakdown of the key components:
#
# **Symmetric-key:**  The same key is used for encrypting and decrypting the data. This is like using the same key to lock and unlock a door. Both the sender and the receiver need to have a copy of the secret key.
#
# **Block Cipher:** The data is divided into fixed-size blocks (e.g., 64 bits or 128 bits). Each block is then encrypted independently using the key. If the input data is not an exact multiple of the block size, it is padded to make it fit.
#
# **How it Works**
#
# 1. **Plaintext:** The original message or data to be encrypted.
# 2. **Key:** The secret key shared between the sender and receiver.
# 3. **Encryption Algorithm:** A set of mathematical operations that transforms the plaintext block into ciphertext using the key.
# 4. **Ciphertext:** The encrypted, unreadable version of the plaintext.
# 5. **Decryption Algorithm:** The reverse of the encryption algorithm, using the same key to transform the ciphertext back into the original plaintext.
#
# **Examples of Symmetric-Key Block Ciphers**
#
# * **DES (Data Encryption Standard):**  A classic block cipher that was widely used but is now considered outdated due to its short key length.
# * **3DES (Triple DES):** An enhancement of DES that applies DES three times to each block, providing increased security.
# * **AES (Advanced Encryption Standard):** The current standard for symmetric encryption, known for its security and efficiency.
#
# **Modes of Operation**
#
# Block ciphers can be used in different modes of operation to handle how data is encrypted when it's longer than a single block. Common modes include:
#
# * **ECB (Electronic Codebook):** The simplest mode, where each block is encrypted independently.
# * **CBC (Cipher Block Chaining):**  Each plaintext block is XORed with the previous ciphertext block before encryption, adding dependency between blocks.
# * **CTR (Counter):**  The cipher encrypts a counter value and XORs it with the plaintext, turning the block cipher into a stream cipher.
#
# **Advantages**
#
# * **Efficiency:** Block ciphers are generally efficient for encrypting large amounts of data.
# * **Strong Security:**  With a strong key and a well-designed algorithm, block ciphers can provide robust confidentiality.
#
# **Disadvantages**
#
# * **Key Management:** Securely distributing and managing the secret key can be challenging.
# * **Padding:**  Handling data that is not an exact multiple of the block size requires padding, which can sometimes introduce vulnerabilities if not implemented correctly.
#
# **Applications**
#
# Symmetric-key block ciphers are used in a wide variety of applications, including:
#
# * **Data Encryption:**  Encrypting files, databases, and other sensitive information.
# * **Secure Communication:**  Securing communication protocols like HTTPS and VPNs.
# * **Password Storage:**  Hashing passwords to protect them from unauthorized access.
#
# Understanding symmetric-key block ciphers is fundamental to understanding modern cryptography and its applications in securing digital information.

# %% [markdown]
# ## Data Encryption Standards
#
# * **Type:** Symmetric-key block cipher
# * **Block Size:** 64 bits
# * **Key Size:** 56 bits (effectively, with 8 bits used for parity)
# * **Structure:** Feistel network
# * **Rounds:** 16 rounds of encryption
# * **Key Schedule:**  A different 48-bit subkey is generated for each round.
# * **Operations:**  DES uses a combination of permutations, substitutions, and XOR operations in its round function.
# * **History:**
#     * Developed in the early 1970s by IBM, with input from the National Security Agency (NSA).
#     * Adopted as a Federal Information Processing Standard (FIPS) in 1977.
#     * Widely used for several decades in various applications, including finance and government.
# * **Weaknesses:**
#     * **Short key length:** The 56-bit key is vulnerable to brute-force attacks with modern computing power.
#     * **Cryptanalytic attacks:**  Some cryptanalytic techniques, like differential cryptanalysis, have been developed that can weaken DES.
# * **Replacement:**  Due to its vulnerabilities, DES has been largely replaced by more secure algorithms like Triple DES (3DES) and the Advanced Encryption Standard (AES).
# * **Significance:**
#     * DES played a crucial role in the development and understanding of modern cryptography.
#     * It served as a benchmark for evaluating the security of new encryption algorithms.
#     * Its standardization and widespread adoption led to significant advancements in the field of cryptography.
#
# **Key takeaways:**
#
# * DES is a classic example of a Feistel cipher and was a significant milestone in the history of cryptography.
# * Despite its historical importance, DES is no longer considered secure for most applications due to its short key length and vulnerabilities to attacks.
# * Understanding DES provides valuable insights into the evolution of encryption algorithms and the importance of continuous improvement in security.

# %% [markdown]
# The following code implements a basic Feistel network with a simple round function. It demonstrates the core concepts of splitting data, applying a round function, and swapping halves in each round.
#
# This basic example can be a starting point for further exploration and experimentation with different round functions, key schedules, and numbers of rounds to illustrate the flexibility and security of Feistel networks.

# %%
# def round_function(right_half, key):
#     """
#     A simple round function for a 4-bit Feistel cipher.
#     """
#     # Example: XOR with the key
#     return right_half ^ key

# def feistel_encrypt(plaintext, key, rounds):
#     """
#     Encrypts a 4-bit plaintext using a Feistel cipher.
#     """
#     # Split the 4-bit plaintext into two 2-bit halves
#     left = (plaintext >> 2) & 0b11
#     right = plaintext & 0b11

#     print(f"Initial plaintext: {plaintext:04b}, left: {left:02b}, right: {right:02b}")

#     for i in range(rounds):
#         temp = left
#         left = right
#         right = temp ^ round_function(right, key)

#         print(f"Round {i+1}: left: {left:02b}, right: {right:02b}")

#     # Combine the halves to form the ciphertext
#     ciphertext = (left << 2) | right
#     return ciphertext

# def feistel_decrypt(ciphertext, key, rounds):
#     """
#     Decrypts a 4-bit ciphertext using a Feistel cipher.
#     """
#     # Split the 4-bit ciphertext into two 2-bit halves
#     left = (ciphertext >> 2) & 0b11
#     right = ciphertext & 0b11

#     print(f"Initial ciphertext: {ciphertext:04b}, left: {left:02b}, right: {right:02b}")

#     # Perform the rounds in reverse for decryption
#     for i in range(rounds):
#         temp = right
#         right = left ^ round_function(right, key)
#         left = temp

#         print(f"Round {rounds-i}: left: {left:02b}, right: {right:02b}")

#     # Combine the halves to form the plaintext
#     plaintext = (left << 2) | right
#     return plaintext

# %%
# Example usage

# %% [markdown]
# XOR (exclusive OR) is a logical operation that compares two bits and returns:
#
# * 1 if the bits are different (one is 0 and the other is 1)
# * 0 if the bits are the same (both are 0 or both are 1)
#
# Let's break down the example `11 XOR 0110 = 0101` bit by bit:
#
# 1. **Align the bits:** Since 11 is shorter than 0110, we can assume it's 0011 to make the lengths match:
#
#    ```
#    0011
#    0110
#    ----
#    ```
#
# 2. **Compare each pair of bits:**
#
#    * **First bit:** 0 XOR 0 = 0
#    * **Second bit:** 0 XOR 1 = 1
#    * **Third bit:** 1 XOR 1 = 0
#    * **Fourth bit:** 1 XOR 0 = 1
#
# 3. **Combine the results:**
#
#    ```
#    0011
#    0110
#    ----
#    0101
#    ```
#
# Therefore, `11 XOR 0110 = 0101`.
#
# **Key Properties of XOR**
#
# * **Reversibility:** If you XOR the result with one of the original inputs, you get the other input back. For example:
#    * `0101 XOR 0110 = 0011`
#    * `0101 XOR 0011 = 0110`
#
# * **Commutativity:** The order of the inputs doesn't matter:
#    * `11 XOR 0110 = 0110 XOR 11`
#
# * **Associativity:**  You can group multiple XOR operations in any order:
#    * `(A XOR B) XOR C = A XOR (B XOR C)`
#
# **Use in Cryptography**
#
# XOR is frequently used in cryptography because of its properties:
#
# * **Simple to implement:** It's a basic bitwise operation that's fast and efficient.
# * **Reversibility:** This is crucial for decryption in many ciphers.
# * **Security:**  When combined with other operations, XOR can contribute to creating strong and unpredictable encryption transformations.
#
# I hope this explanation clarifies how XOR works!

# %% [markdown]
# **Initial State:**
#
# * `plaintext = 1011`
# * `left = 10`
# * `right = 11`
# * `key = 0110`
#
# **Round 1:**
#
# 1. **Swap:** The `right` half (`11`) becomes the new `left`:
#    * `new_left = 11`
#
# 2. **Round Function:**
#    * `right_half XOR key = 11 XOR 0110 = 0101`
#    * `(0101 << 2) | (0101 >> 2) =  0100 | 0001 = 0101`
#
# 3. **XOR with Original Left:**  This is where the mistake was happening! The result of the round function (`0101`) should be XORed with the *original* `left` half (`10`), not the new `left` (`11`):
#     * `new_right = 10 XOR 0101 = 0111`
#
# Therefore, after Round 1:
#
# * `left = 11` (the previous `right`)
# * `right = 111` (calculated as shown above)

# %% [markdown]
# In the simple example provided, the round function is just an XOR operation:
#
# ```python
# def round_function(right_half, key):
#     """
#     A simple round function (can be made more complex).
#     """
#     # Example: XORing with the key
#     return right_half ^ key
# ```
#
# However, in real-world ciphers, the round function is much more complex.  The goal of the round function is to introduce confusion and diffusion into the encryption process:
#
# * **Confusion:**  Making the relationship between the key and the ciphertext as complex and obscure as possible.
# * **Diffusion:** Spreading the influence of each bit of the plaintext throughout the ciphertext.
#
# Here are some common operations used in round functions of real-world Feistel ciphers:
#
# * **Substitution boxes (S-boxes):**  These are lookup tables that map input bits to output bits in a non-linear way.  S-boxes introduce confusion by making the relationship between the input and output difficult to analyze.
# * **Permutation boxes (P-boxes):** These rearrange the order of bits, contributing to diffusion by spreading the influence of each bit.
# * **Modular arithmetic:**  Operations like addition and multiplication modulo a number can introduce non-linearity and complexity.
# * **Bitwise operations:**  XOR, AND, OR, and other bitwise operations can be combined in various ways to create complex transformations.
# * **Arithmetic operations:**  Addition, subtraction, multiplication, and sometimes division can be used.
#
# **Example of a More Complex Round Function:**
#
# ```python
# def complex_round_function(right_half, key):
#   """
#   A more complex round function example.
#   """
#   # 1. Perform bitwise operations (e.g., XOR with the key)
#   temp = right_half ^ key
#
#   # 2. Apply an S-box (lookup table)
#   sbox =  # Example S-box
#   temp = sbox[temp]
#
#   # 3. Perform modular arithmetic (e.g., addition modulo 16)
#   temp = (temp + key) % 16
#
#   # 4. Apply a P-box (bit permutation)
#   temp = ((temp & 0b1001) << 1) | ((temp & 0b0110) >> 1)  # Example permutation
#
#   return temp
# ```
#
# This is still a simplified example, but it shows how different operations can be combined to create a more complex and secure round function.
#
# **Key Takeaways**
#
# * The round function is critical for the security of a Feistel cipher.
# * A strong round function should introduce confusion and diffusion.
# * Real-world ciphers use a combination of operations to create complex and secure round functions.
# * Analyzing and designing round functions is an important aspect of cryptography.

# %% [markdown]
# ## 3DES
#
# 3DES (Triple DES) is a symmetric-key block cipher that was designed to overcome the vulnerabilities of the original Data Encryption Standard (DES) cipher. For example, 168 bit key length on a 64 bit block (8 characters, or 8 bytes, 1 byte = 8 bits).
#
# * **64-bit block:** This refers to the size of the data block that 3DES encrypts at a time.  Like the original DES, 3DES takes a 64-bit chunk of your message and scrambles it using the encryption keys.
#
# * **168-bit key length:** This is where 3DES gets its enhanced security. It uses *three* different 56-bit DES keys.
#
#     * So, you have Key 1, Key 2, and Key 3.
#     * 56 bits x 3 keys = 168 bits
#
# **Why is this important?**
#
# * **Increased security:**  A longer key length makes it much harder for an attacker to guess the key using a brute-force attack (trying every possible key).  With 168 bits, there are an astronomical number of possible keys to try.
# * **Overcoming DES's weakness:**  The original DES, with its 56-bit key, became vulnerable to brute-force attacks as computing power increased. 3DES was designed to address this weakness by effectively increasing the key length.
#
# **Think of it like this:**
#
# Imagine you have a simple padlock with a 3-digit combination. It's relatively easy to try all the possible combinations (000 to 999) to open the lock. Now imagine you have three of these padlocks chained together. To open it, you need to know the correct combination for all three locks. This makes it much harder to crack!
#
# **Important Note:**
#
# While 3DES with a 168-bit key length is much more secure than DES, it's still less efficient than modern ciphers like AES because it has to perform the DES algorithm three times for each block of data. That's why AES is generally preferred for new applications.
#
# Let me know if you'd like a deeper dive into how 3DES uses those three keys in its encryption process!
#
# **How it Works**
#
# 3DES applies the DES algorithm three times to each data block. Here's the basic process:
#
# 1. **Encryption:**
#    * **DES Encryption:** The plaintext block is encrypted with the first key (K1).
#    * **DES Decryption:** The result from the previous step is *decrypted* with the second key (K2).
#    * **DES Encryption:** The result from the previous step is encrypted again with the third key (K3).
#
# 2. **Decryption:** The process is reversed using the keys in reverse order (K3, K2, K1).
#
# **Keying Options**
#
# There are a few different ways to use keys in 3DES:
#
# * **Keying Option 1:** All three keys are independent. This provides the strongest security with an effective key length of 168 bits.
# * **Keying Option 2:**  K1 and K2 are independent, and K3 = K1. This option has an effective key length of 112 bits.
# * **Keying Option 3:** All three keys are identical (K1 = K2 = K3). This is essentially the same as using the original DES algorithm and is not recommended.
#
# **Security**
#
# 3DES is significantly more secure than DES due to the increased effective key length.  However, it's important to note:
#
# * **Keying Option 2:** While more secure than DES, this option with 112 bits is still considered less secure than Keying Option 1 with 168 bits.
# * **Performance:** 3DES is slower than DES and other modern ciphers like AES because it requires three DES operations for each block.
#
# **Why 3DES was Developed**
#
# * **DES Vulnerabilities:**  As computing power increased, the 56-bit key length of DES became vulnerable to brute-force attacks.
# * **Backward Compatibility:**  3DES was designed to leverage existing DES implementations while providing increased security.
#
# **Current Status**
#
# While 3DES was widely used for a period, it's now considered a legacy algorithm.
#
# * **NIST Deprecation:** The National Institute of Standards and Technology (NIST) has deprecated 3DES for most new applications.
# * **AES as the Standard:** The Advanced Encryption Standard (AES) is now the recommended standard for symmetric encryption due to its better security and performance.
#
# **Key Takeaways**
#
# * 3DES demonstrates how cryptographic algorithms evolve to address vulnerabilities.
# * It's a good example of extending the lifespan of an existing algorithm while improving security.
# * Understanding 3DES provides context for appreciating the advancements in modern encryption algorithms like AES.

# %% [markdown]
# ## Advanced Encryption Standard (AES)
#
# AES (Advanced Encryption Standard) is a symmetric-key block cipher that is widely used as the standard for encrypting electronic data today. It was established by the U.S. National Institute of Standards and Technology (NIST) in 2001.
#
# Here's a breakdown of AES:
#
# **How it Works**
#
# AES operates on a 128-bit block of data and supports three key lengths: 128, 192, or 256 bits. The algorithm uses a series of transformations to convert the plaintext into ciphertext. These transformations are arranged in rounds, and the number of rounds depends on the key length:
#
# * 128-bit key: 10 rounds
# * 192-bit key: 12 rounds
# * 256-bit key: 14 rounds
#
# **Key Steps in Each Round:**
#
# 1. **SubBytes:** A non-linear substitution step where each byte is replaced with another byte using a lookup table (S-box).
# 2. **ShiftRows:** The bytes in the 4x4 matrix (representing the 128-bit block) are shifted cyclically.
# 3. **MixColumns:** A mixing operation that combines the four bytes in each column of the matrix.
# 4. **AddRoundKey:** The 128-bit round key is XORed with the state matrix.
#
# **Key Schedule**
#
# AES uses a key schedule to generate a different round key for each round from the original encryption key.
#
# **Security**
#
# AES is considered very secure and has not been practically broken. Its strength comes from:
#
# * **Strong Algorithm:** The combination of transformations provides excellent confusion and diffusion, making it resistant to cryptanalysis.
# * **Variable Key Length:** The support for different key lengths offers flexibility and increased security.
# * **Extensive Analysis:** AES has undergone extensive public scrutiny and analysis, and no significant vulnerabilities have been found.
#
# **Advantages of AES**
#
# * **Security:**  AES is highly resistant to known attacks.
# * **Performance:** It is relatively fast and efficient on both hardware and software platforms.
# * **Flexibility:** It supports different key lengths and can be implemented in various modes of operation.
# * **Open Standard:** AES is a publicly available and royalty-free standard.
#
# **Applications of AES**
#
# AES is used in a wide range of applications, including:
#
# * **Securing Communication Protocols:**  HTTPS, TLS/SSL, Wi-Fi (WPA2 and WPA3), and VPNs.
# * **Data Encryption:** Encrypting files, databases, and other sensitive information.
# * **Hardware Encryption:**  Used in devices like hard drives, SSDs, and secure microcontrollers.
#
# **Key Takeaways**
#
# * AES is the current gold standard for symmetric encryption.
# * Understanding its structure and operations provides valuable insights into modern cryptography.
# * AES demonstrates the importance of rigorous design and analysis in creating secure cryptographic algorithms.

# %% [markdown]
# ## Asymmetric Encryption
#
# Asymmetric encryption, also known as public-key cryptography, is a revolutionary concept in cryptography that uses a pair of keys for encryption and decryption: a public key and a private key.
#
# **How it works:**
#
# 1. **Key Pair Generation:**  A user generates a key pair consisting of a public key and a private key.
# 2. **Public Key Distribution:** The public key can be freely shared with anyone.
# 3. **Encryption:**  Someone who wants to send a secure message to the user uses the recipient's public key to encrypt the message.
# 4. **Decryption:** Only the recipient, who possesses the corresponding private key, can decrypt the message.
#
# **Key Properties:**
#
# * **Confidentiality:**  Only the holder of the private key can decrypt messages encrypted with the corresponding public key.
# * **Authentication:** The sender can use their private key to create a digital signature, which can be verified using their public key. This ensures that the message truly came from the claimed sender.
#
# **Historical Context**
#
# * **Early Ideas (1960s-1970s):**  The concept of public-key cryptography was first explored in the late 1960s and early 1970s by cryptographers like Whitfield Diffie, Martin Hellman, and Ralph Merkle. They were looking for ways to solve the key distribution problem inherent in symmetric encryption (how to securely share the same key between parties).
# * **First Practical Implementation (1977):**  Ron Rivest, Adi Shamir, and Leonard Adleman (RSA) developed the first practical public-key cryptosystem in 1977. The RSA algorithm is based on the mathematical difficulty of factoring large numbers.
# * **Diffie-Hellman Key Exchange (1976):**  Whitfield Diffie and Martin Hellman proposed a key exchange protocol that allows two parties to establish a shared secret key over an insecure channel. This protocol was a major breakthrough in public-key cryptography.
# * **Elliptic Curve Cryptography (1980s):**  Neal Koblitz and Victor S. Miller independently proposed using elliptic curves for cryptography in the mid-1980s. Elliptic curve cryptography (ECC) offers similar security to RSA with shorter key lengths, making it more efficient.
#
# **Impact and Applications**
#
# Asymmetric encryption has had a profound impact on modern communication and security:
#
# * **Secure Online Communication:**  It forms the foundation of secure protocols like HTTPS (for secure web browsing) and TLS/SSL (for secure data transmission).
# * **Digital Signatures:**  Used for verifying the authenticity and integrity of digital documents and software.
# * **Cryptocurrencies:**  Public-key cryptography is essential for securing transactions and managing ownership in cryptocurrencies like Bitcoin.
# * **Key Management:**  Asymmetric encryption helps simplify key management by eliminating the need to securely share secret keys for every communication pair.
#
# **Challenges**
#
# * **Computational Cost:**  Asymmetric encryption is generally more computationally expensive than symmetric encryption.
# * **Key Management:**  While public-key cryptography simplifies key distribution, it still requires secure storage and management of private keys.
#
# Asymmetric encryption is a cornerstone of modern cryptography. Its development has enabled secure communication and digital trust in the online world, paving the way for e-commerce, online banking, and countless other applications.
#
# **Code Explanation:**
#
# * **`cryptography.hazmat`:** This module provides the necessary tools for asymmetric encryption.
# * **`generate_key_pair()`:** Creates a private key and its corresponding public key using the RSA algorithm.
# * **`encrypt_message()`:** Encrypts the message using the recipient's public key. OAEP padding is used for enhanced security.
# * **`decrypt_message()`:** Decrypts the ciphertext using the recipient's private key.
#
# **To run this code:**
#
# 1.  Install the `cryptography` library:
# 2.  Save the code as a Python file (e.g., `asymmetric_encryption.py`).
# 3.  Run the file: `python asymmetric_encryption.py`
#
# **Key Concepts for Your Class:**
#
# * **Public-Key Cryptography:** Explain the core idea of having two keys: one for encryption (public key) and one for decryption (private key).
# * **RSA Algorithm:** Discuss the RSA algorithm and its mathematical foundation (based on the difficulty of factoring large numbers).
# * **Digital Signatures:**  Explain how asymmetric encryption can be used for digital signatures to verify the authenticity and integrity of messages.
# * **Key Distribution:**  Discuss the challenges and solutions for securely distributing public keys (e.g., using certificates).
#
# **Class Activity Ideas:**
#
# * **Key Exchange:** Have students simulate a secure key exchange protocol (e.g., Diffie-Hellman) to establish a shared secret key for symmetric encryption.
# * **Digital Signature Verification:**  Have students write code to generate and verify digital signatures using asymmetric encryption.
# * **Real-World Applications:** Explore applications like SSL/TLS (used in HTTPS), email encryption (PGP), and cryptocurrencies.

# %% [markdown]
# ### Asymmetric Encryption (RSA)
#
# RSA (Rivest-Shamir-Adleman) is a widely used public-key cryptosystem that is named after its inventors: Ron Rivest, Adi Shamir, and Leonard Adleman. It's based on the mathematical difficulty of factoring large numbers.
#
# **Here's how RSA works:**
#
# **1. Key Generation:**
#
# * **Choose two distinct prime numbers, p and q.** These should be large prime numbers for strong security.
# * **Calculate n = p * q.**  `n` is called the modulus and is used for both the public and private keys.
# * **Calculate the totient of n: φ(n) = (p - 1) * (q - 1).**
# * **Choose an integer e (the public exponent) such that 1 < e < φ(n) and gcd(e, φ(n)) = 1.**  In simpler terms, `e` and `φ(n)` should have no common factors other than 1 (they are relatively prime). A common choice for `e` is 65537.
# * **Calculate d (the private exponent) such that d * e ≡ 1 (mod φ(n)).**  In other words, `d` is the modular multiplicative inverse of `e` modulo `φ(n)`.
#
# **2. Encryption:**
#
# * **Plaintext:**  The message to be encrypted, represented as a number M.
# * **Ciphertext:**  Calculated as C = M<sup>e</sup> mod n.
#
# **3. Decryption:**
#
# * **Plaintext:** Calculated as M = C<sup>d</sup> mod n.
# * Where e = public key and d = private key
#
# **Security of RSA**
#
# The security of RSA relies on the fact that it's computationally difficult to factor a large number (`n`) into its prime factors (`p` and `q`).  If an attacker could factor `n`, they could easily calculate `φ(n)` and then `d`, the private key.  However, for sufficiently large `n` (typically 2048 bits or more), factoring is considered infeasible with current technology.
#
# **Applications of RSA**
#
# RSA is widely used for:
#
# * **Secure Communication:**  TLS/SSL, the protocol that secures HTTPS websites, uses RSA for key exchange and digital signatures.
# * **Digital Signatures:**  RSA can be used to create digital signatures to verify the authenticity and integrity of digital documents.
# * **Key Exchange:**  RSA can be used to securely exchange symmetric keys, which are then used for faster encryption of bulk data.
# * **Cryptocurrencies:**  RSA is used in some cryptocurrencies for managing digital signatures and securing transactions.
#
# **Key Takeaways**
#
# * RSA is a fundamental public-key cryptosystem that has played a crucial role in enabling secure communication and digital trust.
# * Its security relies on the difficulty of factoring large numbers.
# * RSA is widely used in various applications, including secure online communication, digital signatures, and cryptocurrencies.

# %%
# from cryptography.hazmat.backends import default_backend
# from cryptography.hazmat.primitives.asymmetric import rsa
# from cryptography.hazmat.primitives import serialization
# from cryptography.hazmat.primitives import hashes
# from cryptography.hazmat.primitives.asymmetric import padding

# def generate_key_pair():
#     """
#     Generates a public/private key pair.
#     """
#     private_key = rsa.generate_private_key(
#         public_exponent=65537,
#         key_size=2048,
#         backend=default_backend()
#     )
#     public_key = private_key.public_key()
#     return private_key, public_key

# def encrypt_message(message, public_key):
#     """
#     Encrypts a message using the public key.
#     """
#     ciphertext = public_key.encrypt(
#         message.encode(),
#         padding.OAEP(
#             mgf=padding.MGF1(algorithm=hashes.SHA256()),
#             algorithm=hashes.SHA256(),
#             label=None
#         )
#     )
#     return ciphertext

# def decrypt_message(ciphertext, private_key):
#     """
#     Decrypts a message using the private key.
#     """
#     plaintext = private_key.decrypt(
#         ciphertext,
#         padding.OAEP(
#             mgf=padding.MGF1(algorithm=hashes.SHA256()),
#             algorithm=hashes.SHA256(),
#             label=None
#         )
#     )
#     return plaintext.decode()

# %%
# Example usage

# %% [markdown]
# ### Private and Public Keys
#
# **Who has the private key?**
#
# The private key is kept secret and held **only by the owner of the website** or the entity that the certificate was issued to.  It's never transmitted over the internet or shared with the browser.
#
# **How does the website get the private key?**
#
# 1. **Key Generation:** The website owner generates a private key. This is typically done on the web server itself or using a secure key management system.
#
# 2. **Certificate Signing Request (CSR):** The website owner creates a CSR, which includes their public key (derived from the private key) and identifying information.
#
# 3. **Certificate Authority (CA):** The CSR is sent to a trusted Certificate Authority (CA) like Let's Encrypt, Sectigo, or DigiCert. The CA verifies the website owner's identity.
#
# 4. **Certificate Issuance:**  If the CA approves the request, it issues a certificate containing the website's public key and other information, signed with the CA's private key.
#
# 5. **Installation:** The website owner installs the certificate and the private key on their web server.
#
# **How is the private key used?**
#
# * **TLS/SSL Handshake:** When you connect to a website using HTTPS, a TLS/SSL handshake occurs. The website's certificate is sent to your browser.
# * **Key Exchange:**  The browser uses the public key in the certificate to establish a shared secret key with the website.
# * **Symmetric Encryption:** The shared secret key is then used for encrypting and decrypting the actual data transmitted during your browsing session.
# * **Server Decryption:**  The website uses its private key to decrypt the data that you send (e.g., form submissions, login credentials).
#
# **Why is this important?**
#
# * **Confidentiality:** Only the website with the private key can decrypt the data you send, protecting it from eavesdropping.
# * **Authentication:** The certificate ensures that you are communicating with the legitimate website and not an imposter.
# * **Integrity:** The digital signature on the certificate ensures that the data hasn't been tampered with in transit.
#
# **Key takeaway:**
#
# The private key is a crucial component of website security. It's kept secret by the website owner and used to establish secure connections and decrypt sensitive information. The browser only needs the public key (from the certificate) to initiate the secure communication process.

# %% [markdown]
# ### Asymmetric Encryption (Diffie-Hellman)
#
# The Diffie-Hellman (DH) key exchange is a remarkable cryptographic protocol that allows two parties to establish a shared secret key over an insecure communication channel. This shared key can then be used for secure communication using symmetric encryption.
#
# **Here's how it works:**
#
# 1. **Public Parameters:**
#    - Alice and Bob agree on two public numbers: a prime number `p` and a generator `g` (where `g` is a primitive root modulo `p`).
#
# 2. **Individual Key Generation:**
#    - **Alice:** Chooses a secret integer `a` (her private key) and calculates `A = g^a mod p` (her public key).
#    - **Bob:** Chooses a secret integer `b` (his private key) and calculates `B = g^b mod p` (his public key).
#
# 3. **Exchange Public Keys:**
#    - Alice sends her public key `A` to Bob.
#    - Bob sends his public key `B` to Alice.
#
# 4. **Calculate Shared Secret:**
#    - **Alice:** Receives Bob's public key `B` and calculates the shared secret `s = B^a mod p`.
#    - **Bob:** Receives Alice's public key `A` and calculates the shared secret `s = A^b mod p`.
#
# **The Magic:**
#
# Both Alice and Bob arrive at the same shared secret key `s` without ever directly transmitting it over the insecure channel. This is because:
#
# - `s = B^a mod p = (g^b mod p)^a mod p = g^(b*a) mod p`
# - `s = A^b mod p = (g^a mod p)^b mod p = g^(a*b) mod p`
#
# **Security**
#
# The security of Diffie-Hellman relies on the difficulty of the Discrete Logarithm Problem (DLP): given `g`, `p`, and `g^a mod p`, it's computationally difficult to determine the secret exponent `a`.
#
# **Why is Diffie-Hellman Important?**
#
# * **Key Exchange:** It solves the key distribution problem in symmetric encryption by enabling secure key agreement without pre-sharing secrets.
# * **Forward Secrecy:** Even if an attacker compromises one of the private keys in the future, they cannot decrypt past communications because the shared secret was never transmitted.
# * **Foundation for Other Protocols:** Diffie-Hellman is used as a building block in many security protocols, such as TLS/SSL, SSH, and IPsec.
#
# **Key Takeaways**
#
# * Diffie-Hellman is a key exchange protocol, not an encryption algorithm itself.
# * It allows two parties to securely establish a shared secret key over an insecure channel.
# * Its security is based on the difficulty of the Discrete Logarithm Problem.
# * It's a foundational component of many modern security protocols.
#
# **Code Explanation:**
#
# 1.  **`generate_dh_parameters()`:** Creates the Diffie-Hellman parameters, including a prime modulus and a generator, which are shared between both parties.
# 2.  **`generate_private_key()`:**  Generates a private key for a party.
# 3.  **`generate_public_key()`:** Generates a public key corresponding to the private key.
# 4.  **`derive_shared_key()`:** This is where the magic happens! Each party uses their own private key and the other party's public key to calculate the shared secret.  This function also uses HKDF (HMAC-based Key Derivation Function) to derive a strong, fixed-length key from the raw Diffie-Hellman shared secret.

# %%
# import cryptography.hazmat.backends as default_backend
# from cryptography.hazmat.primitives import hashes
# from cryptography.hazmat.primitives.asymmetric import dh
# from cryptography.hazmat.primitives.kdf.hkdf import HKDF

# def generate_dh_parameters():
#     """
#     Generates Diffie-Hellman parameters.
#     """
#     # Get the default backend using default_backend.default_backend()
#     backend = default_backend.default_backend()
#     parameters = dh.generate_parameters(generator=2, key_size=2048,
#                                            backend=backend)
#     return parameters

# def generate_private_key(parameters):
#     """
#     Generates a private key given DH parameters.
#     """
#     private_key = parameters.generate_private_key()
#     return private_key

# def generate_public_key(private_key):
#     """
#     Generates a public key from a private key.
#     """
#     public_key = private_key.public_key()
#     return public_key

# def derive_shared_key(private_key, peer_public_key):
#     """
#     Derives a shared key from your private key and the peer's public key.
#     """
#     shared_key = private_key.exchange(peer_public_key)
#     # Get the default backend using default_backend.default_backend()
#     backend = default_backend.default_backend()
#     derived_key = HKDF(
#         algorithm=hashes.SHA256(),
#         length=32,
#         salt=None,
#         info=b'handshake data',
#         backend=backend
#     ).derive(shared_key)
#     return derived_key

# %%
# Example usage:

# %% [markdown]
# ## Certificates and PKI (Public Key Infrastructure)
#
# Imagine you're meeting someone online for the first time. How do you know they are who they claim to be?  That's where certificates and Public Key Infrastructure (PKI) come in!
#
# **What are Certificates?**
#
# * **Digital Identity Cards:** Think of a certificate like a digital passport or driver's license. It verifies the identity of an individual, organization, or device.
# * **Contains Important Information:** A certificate includes:
#     - **Subject:** The identity being verified (e.g., a website's domain name, a person's email address).
#     - **Public Key:** The subject's public key.
#     - **Issuer:** The entity that issued the certificate (a Certificate Authority).
#     - **Validity Period:**  The time frame during which the certificate is valid.
#     - **Digital Signature:**  A signature created by the issuer to ensure the certificate's integrity.
#
# **What is Public Key Infrastructure (PKI)?**
#
# * **System for Trust:** PKI is the system and processes that manage digital certificates. It's like the government agency that issues and verifies passports.
# * **Key Components:**
#     - **Certificate Authority (CA):**  A trusted entity that issues and verifies certificates.  Think of them as the "passport office" of the digital world.  Examples include Let's Encrypt, Sectigo, and DigiCert.
#     - **Registration Authority (RA):**  Helps the CA with verifying the identity of entities requesting certificates.
#     - **Certificate Repository:** A database where certificates are stored and can be accessed.
#
# **How Certificates and PKI Work Together**
#
# 1. **Request a Certificate:**  An individual or organization requests a certificate from a CA.
# 2. **Identity Verification:** The CA (or RA) verifies the identity of the requester.
# 3. **Certificate Issuance:**  The CA issues a certificate containing the subject's information and public key, signed with the CA's private key.
# 4. **Trust Chain:**  Your computer or browser has a list of trusted root CA certificates. When you encounter a new certificate, it checks if it was issued by a trusted CA or by an intermediate CA that chains back to a trusted root CA.  This establishes trust.
#
# **Why are Certificates and PKI Important?**
#
# * **Authentication:**  Verify the identity of websites, individuals, and devices.
# * **Data Integrity:**  Ensure that data has not been tampered with in transit.
# * **Confidentiality:**  Enable secure communication by facilitating the exchange of encryption keys.
#
# **Examples of Certificate Use**
#
# * **HTTPS Websites:**  When you visit a website with HTTPS, your browser checks the website's certificate to verify its identity and establish a secure connection.
# * **Email Encryption:**  Certificates can be used to encrypt and sign emails, ensuring that only the intended recipient can read them.
# * **Code Signing:**  Certificates can be used to verify the authenticity and integrity of software downloads.
#
# **Key Takeaways**
#
# * Certificates are digital identity cards that verify the identity of entities online.
# * PKI is the system that manages digital certificates.
# * Certificates and PKI are crucial for establishing trust and security in the digital world.
#
# Understanding certificates and PKI is essential for navigating the internet safely and for understanding how digital trust is established in various applications.
#
# **Code Explanation:**
#
# * **`generate_private_key()`:** Generates an RSA private key and saves it to a PEM file.
# * **`generate_csr()`:** Creates a Certificate Signing Request (CSR) containing information about the entity requesting the certificate (e.g., domain name, organization).
# * **`sign_certificate()`:** Simulates a Certificate Authority (CA) signing the CSR using its private key. In a real-world scenario, you would send the CSR to a trusted CA like Let's Encrypt or Sectigo.
#
# **Important Notes:**
#
# * This example is a simplified simulation.  Real-world PKI involves more complex processes and considerations.
# * For production environments, use well-established CAs and follow security best practices.
# * Consider using a dedicated library like `certbot` for obtaining certificates from Let's Encrypt.

# %%
# from cryptography import x509
# from cryptography.x509.oid import NameOID
# from cryptography.hazmat.backends import default_backend
# from cryptography.hazmat.primitives import hashes
# from cryptography.hazmat.primitives.asymmetric import rsa
# from cryptography.hazmat.primitives import serialization
# from cryptography.hazmat.primitives.serialization import NoEncryption

# def generate_private_key(filename="key.pem"):
#     """
#     Generates a private key and saves it to a file.
#     """
#     key = rsa.generate_private_key(
#         public_exponent=65537,
#         key_size=2048,
#         backend=default_backend()
#     )
#     with open(filename, "wb") as f:
#         f.write(key.private_bytes(
#             encoding=serialization.Encoding.PEM,
#             format=serialization.PrivateFormat.PKCS8,
#             encryption_algorithm=NoEncryption()  # No password protection for this example
#         ))
#     return key

# def generate_csr(private_key, filename="csr.pem"):
#     """
#     Generates a certificate signing request (CSR).
#     """
#     csr = x509.CertificateSigningRequestBuilder().subject_name(x509.Name([
#         # Provide your own information here
#         x509.NameAttribute(NameOID.COUNTRY_NAME, u"US"),
#         x509.NameAttribute(NameOID.STATE_OR_PROVINCE_NAME, u"California"),
#         x509.NameAttribute(NameOID.LOCALITY_NAME, u"San Francisco"),
#         x509.NameAttribute(NameOID.ORGANIZATION_NAME, u"My Company"),
#         x509.NameAttribute(NameOID.COMMON_NAME, u"mysite.com"),
#     ])).add_extension(
#         x509.SubjectAlternativeName([
#             x509.DNSName(u"mysite.com"),
#             x509.DNSName(u"www.mysite.com"),
#         ]),
#         critical=False,
#     ).sign(private_key, hashes.SHA256(), default_backend())

#     with open(filename, "wb") as f:
#         f.write(csr.public_bytes(serialization.Encoding.PEM))
#     return csr

# def sign_certificate(csr, ca_private_key, ca_cert, filename="signed_cert.pem"):
#     """
#     Signs a certificate signing request (CSR) using a CA's private key
#     and certificate.
#     """
#     builder = x509.CertificateBuilder().subject_name(csr.subject).issuer_name(
#         ca_cert.subject
#     ).public_key(
#         csr.public_key()
#     ).serial_number(
#         x509.random_serial_number()
#     ).not_valid_before(
#         datetime.datetime.utcnow()
#     ).not_valid_after(
#         datetime.datetime.utcnow() + datetime.timedelta(days=365)
#     ).add_extension(
#         x509.SubjectAlternativeName([
#             x509.DNSName(u"mysite.com"),
#             x509.DNSName(u"www.mysite.com"),
#         ]),
#         critical=False,
#     )

#     signed_cert = builder.sign(
#         private_key=ca_private_key, algorithm=hashes.SHA256(),
#         backend=default_backend()
#     )

#     with open(filename, "wb") as f:
#         f.write(signed_cert.public_bytes(serialization.Encoding.PEM))
#     return signed_cert

# %%
# Example Usage (Simplified)

# %% [markdown]
# ### CSR
#
# A Certificate Signing Request (CSR) is a formal request sent to a Certificate Authority (CA) to obtain a digital certificate. It's like filling out an application form for a passport or driver's license.
#
# **Information Contained in a CSR:**
#
#   * **Distinguished Name (DN):** This identifies the entity requesting the certificate. It typically includes the following information:
#
#       * **Common Name (CN):** The fully qualified domain name (FQDN) of the website (e.g., [www.example.com](https://www.google.com/url?sa=E&source=gmail&q=https://www.example.com)). This is the most important part of the DN.
#       * **Organization (O):** The legal name of the organization or company.
#       * **Organizational Unit (OU):**  A department or division within the organization (e.g., IT Department).
#       * **Locality (L):** The city or town where the organization is located.
#       * **State or Province (ST):** The state or province where the organization is located.
#       * **Country (C):** The two-letter country code (e.g., US for the United States).
#
#   * **Public Key:** The public key of the entity requesting the certificate. This is the key that will be included in the issued certificate.
#
#   * **Signature Algorithm:** The algorithm used to digitally sign the CSR. This is typically RSA or ECDSA.
#
#   * **Signature:** A digital signature of the CSR created using the requester's private key. This signature ensures the integrity of the CSR and verifies that it came from the entity requesting the certificate.
#
# **Why is a CSR Important?**
#
#   * **Identity Verification:** The information in the CSR allows the CA to verify the identity of the entity requesting the certificate. This helps prevent fraudulent certificate requests.
#   * **Public Key Submission:** The CSR provides the CA with the public key that needs to be included in the certificate.
#   * **Integrity Protection:** The digital signature on the CSR ensures that the information has not been tampered with during transmission.
#
# **Generating a CSR**
#
# CSRs are typically generated using tools like OpenSSL or through web interfaces provided by hosting providers or certificate authorities. The process usually involves:
#
# 1.  **Generating a Private Key:**  The entity requesting the certificate first generates a private key.
# 2.  **Creating the CSR:** The CSR is then created using the private key and the identifying information.
# 3.  **Submitting the CSR:** The CSR is submitted to the CA for processing.
#
# **Key Takeaways**
#
#   * A CSR is a formal request for a digital certificate.
#   * It contains important information about the entity requesting the certificate, including their public key.
#   * The CSR allows the CA to verify the identity of the requester and issue the appropriate certificate.
#
# Understanding the purpose and contents of a CSR is crucial for anyone involved in obtaining or managing digital certificates.

# %% [markdown]
# ### Key
#
# The `key.pem` file typically contains a **private key** in PEM (Privacy Enhanced Mail) format. This private key is a crucial component of Public Key Infrastructure (PKI) and is used for various cryptographic operations.
#
# **Information Contained in `key.pem`:**
#
# * **Private Key:** The core component of the file is the private key itself. This is a unique and secret mathematical value that should be kept confidential. It is used for:
#     * **Decryption:** Decrypting messages that were encrypted with the corresponding public key.
#     * **Digital Signatures:** Creating digital signatures to authenticate the sender of a message or document.
#     * **Authentication:** Authenticating to systems or services that require proof of identity.
#
# * **Key Type:** The file may specify the type of private key, such as RSA, ECDSA, or DSA. Each key type uses different mathematical algorithms.
#
# * **Key Format:** The private key is usually encoded in PKCS#8 format, which is a standard format for storing private keys.
#
# * **Optional Password Protection:** The `key.pem` file might be encrypted with a password to protect the private key from unauthorized access. This adds an extra layer of security.
#
# **Importance of `key.pem`:**
#
# * **Confidentiality:** The private key is essential for decrypting sensitive information and should be kept secret. If it falls into the wrong hands, an attacker could decrypt confidential communications or forge digital signatures.
# * **Authentication:** The private key is used to prove the identity of the holder. This is crucial for secure communication and authentication to various systems.
# * **Integrity:** The private key is used to create digital signatures, which ensure the integrity of messages and documents.
#
# **Security Considerations:**
#
# * **Secure Storage:** The `key.pem` file should be stored securely, preferably in a hardware security module (HSM) or a secure location with access controls.
# * **Strong Passwords:** If the file is password-protected, use a strong and unique password to prevent unauthorized access.
# * **Backups:** Create secure backups of the `key.pem` file to prevent data loss.
# * **Access Control:** Limit access to the private key to authorized personnel only.
#
# **Key Takeaways:**
#
# * The `key.pem` file contains a private key, a crucial component of PKI.
# * The private key is used for decryption, digital signatures, and authentication.
# * Protecting the private key is essential for maintaining security and preventing unauthorized access to sensitive information.
#
# Understanding the contents and importance of the `key.pem` file is crucial for anyone working with PKI and cryptography.

# %% [markdown]
# ### Signed_Cert
#
# The `signed_cert.pem` file contains a digital certificate in PEM (Privacy Enhanced Mail) format. This certificate is issued by a Certificate Authority (CA) and is used to verify the identity of an entity, such as a website, individual, or device.
#
# **Information Contained in `signed_cert.pem`:**
#
# * **Certificate Details:**
#     * **Version:** The version of the X.509 certificate format.
#     * **Serial Number:** A unique identifier assigned to the certificate by the CA.
#     * **Signature Algorithm:** The algorithm used to sign the certificate (e.g., RSA, ECDSA).
#     * **Issuer:** The Distinguished Name (DN) of the CA that issued the certificate.
#     * **Validity Period:** The start and end dates during which the certificate is valid.
#     * **Subject:** The DN of the entity to which the certificate was issued (e.g., website domain name, individual's name).
#
# * **Public Key:** The public key of the certificate holder. This key is used for:
#     * **Encryption:** Encrypting messages that only the certificate holder (who has the corresponding private key) can decrypt.
#     * **Signature Verification:** Verifying digital signatures created by the certificate holder.
#
# * **Extensions:**  Additional information may be included in extensions, such as:
#     * **Subject Alternative Name (SAN):**  Allows the certificate to be valid for multiple domains or IP addresses.
#     * **Key Usage:**  Specifies the purposes for which the public key can be used (e.g., digital signatures, key encipherment).
#
# * **Digital Signature:** A cryptographic signature created by the CA using its private key. This signature:
#     * **Ensures authenticity:** Verifies that the certificate was indeed issued by the CA.
#     * **Guarantees integrity:**  Confirms that the certificate has not been tampered with.
#
# **Importance of `signed_cert.pem`:**
#
# * **Identity Verification:** The certificate provides assurance that the entity presenting it is who they claim to be.
# * **Secure Communication:** The certificate enables secure communication by facilitating the exchange of encryption keys and verifying the identity of the server.
# * **Trust:** The digital signature from the CA establishes trust in the certificate, as the CA is a trusted third party.
#
# **How it Works:**
#
# When you connect to a website using HTTPS, your browser receives the website's `signed_cert.pem` file. The browser then:
#
# 1. **Verifies the CA Signature:** Checks if the certificate was signed by a trusted CA.
# 2. **Checks Validity:** Ensures the certificate is within its validity period.
# 3. **Extracts Public Key:** Obtains the website's public key from the certificate.
# 4. **Establishes Secure Connection:** Uses the public key to initiate a secure, encrypted connection with the website.
#
# **Key Takeaways:**
#
# * The `signed_cert.pem` file contains a digital certificate used to verify identity and enable secure communication.
# * The certificate contains the certificate holder's public key and is digitally signed by a trusted CA.
# * Understanding the information in a certificate is crucial for ensuring secure online interactions.

# %% [markdown]
# ## Using the Certificate
#
# **1. Set up the Colab Notebook**
#
# *   Create a new Colab notebook.
# *   Install the required libraries:
#
# **2. Upload the Certificate**
#
# *   Upload the `signed_cert.pem` file that you generated using the previous PKI code to your Colab environment. You can do this by using the file upload feature in the Colab sidebar.
#
# **Explanation:**
#
# *   **`load_certificate()`:** This function loads the certificate from the `signed_cert.pem` file.
# *   The code then prints various details extracted from the certificate, such as the subject, issuer, validity period, and public key.

# %%
# from cryptography import x509
# from cryptography.hazmat.backends import default_backend

# def load_certificate(filename="signed_cert.pem"):
#     """
#     Loads a certificate from a PEM file.
#     """
#     with open(filename, "rb") as f:
#         cert = x509.load_pem_x509_certificate(f.read(), default_backend())
#     return cert

# # Load the certificate
# cert = load_certificate()

# # Print certificate information
# print("Certificate Subject:", cert.subject)
# print("Certificate Issuer:", cert.issuer)
# print("Certificate Serial Number:", cert.serial_number)
# print("Certificate Not Valid Before:", cert.not_valid_before)
# print("Certificate Not Valid After:", cert.not_valid_after)
# print("Certificate Public Key:", cert.public_key())

# %% [markdown]
# ## Encrypt Decrypt Authorize
#
# You can't directly use an X.509 certificate to encrypt and decrypt text. X.509 certificates are primarily used for authentication and to establish trust, not for encrypting data.
#
# Here's why:
#
# * **Certificates contain public keys:**  X.509 certificates hold the public key of the entity (e.g., a website). Public keys are meant for encryption, but you would encrypt data *to* the entity holding that certificate, not *with* the certificate itself.
# * **Asymmetric encryption limitations:**  Asymmetric encryption (like RSA, which is often used in certificates) is computationally expensive and not ideal for encrypting large amounts of data.
#
# **How encryption usually works with certificates:**
#
# 1. **TLS/SSL handshake:** When you connect to a secure website (HTTPS), your browser uses the website's certificate to verify the server's identity and to establish a secure connection using TLS/SSL.
# 2. **Symmetric key exchange:** During the TLS/SSL handshake, a symmetric key is exchanged between your browser and the server using a key exchange algorithm (often Diffie-Hellman, as we discussed earlier).
# 3. **Symmetric encryption:** The exchanged symmetric key is then used to encrypt and decrypt the actual data transmitted during your session.
#
# **But for Demonstration Purposes:**
#
# * The following code loads the certificate, extracts the public key, and uses it to encrypt some data.
# * To decrypt, you would need the corresponding private key, which is **not** part of the certificate. In real-world applications, the private key is kept secure by the entity that the certificate was issued to.
#
# This example demonstrates how the public key from a certificate can be used for encryption. However, remember that in most secure communication scenarios, symmetric encryption with a key exchanged using the certificate's public key infrastructure is the preferred method for encrypting data.

# %%
# # --- Example Usage (Simplified) ---
# import datetime # Import the datetime module
# from google.colab import files
# from cryptography.hazmat.primitives import serialization

# # 1. Generate a private key for the website
# key = generate_private_key() # Assuming generate_private_key is defined elsewhere

# # 2. Generate a CSR
# csr = generate_csr(key)  # Assuming generate_csr is defined elsewhere

# # ---  (In a real scenario, you would submit the CSR to a CA) ---

# # 3. Simulate a CA signing the certificate (using the same key for simplicity)
# ca_cert = sign_certificate(csr, key, csr) # Assuming sign_certificate is defined elsewhere

# #... your code to generate the certificate...

# # Save the private key to a file
# with open("another_private_key.pem", "wb") as f:
#     f.write(key.private_bytes(
#         encoding=serialization.Encoding.PEM,
#         format=serialization.PrivateFormat.PKCS8,
#         encryption_algorithm=serialization.NoEncryption()
#     ))

# # Save the certificate to a file
# with open("another_signed_cert.pem", "wb") as f:
#     f.write(ca_cert.public_bytes(serialization.Encoding.PEM))

# %%
# from cryptography import x509
# from cryptography.hazmat.backends import default_backend
# from cryptography.hazmat.primitives import hashes, serialization
# from cryptography.hazmat.primitives.asymmetric import padding

# def load_certificate(filename="another_signed_cert.pem"):
#     """
#     Loads a certificate from a PEM file.
#     """
#     with open(filename, "rb") as f:
#         cert = x509.load_pem_x509_certificate(f.read(), default_backend())
#     return cert

# def load_private_key(filename="another_private_key.pem"):
#     """
#     Loads a private key from a PEM file.
#     """
#     with open(filename, "rb") as f:
#         private_key = serialization.load_pem_private_key(
#             f.read(),
#             password=None, # No password for this example,
#                            # use a secure password in production
#             backend=default_backend()
#         )
#     return private_key

# def encrypt_data(data, public_key):
#     """
#     Encrypts data using the public key from the certificate.
#     """
#     ciphertext = public_key.encrypt(
#         data.encode(),
#         padding.OAEP(
#             mgf=padding.MGF1(algorithm=hashes.SHA256()),
#             algorithm=hashes.SHA256(),
#             label=None
#         )
#     )
#     return ciphertext

# def decrypt_data(ciphertext, private_key):
#     """
#     Decrypts data using the corresponding private key
#     (loaded from the private_key.pem file).
#     """
#     plaintext = private_key.decrypt(
#         ciphertext,
#         padding.OAEP(
#             mgf=padding.MGF1(algorithm=hashes.SHA256()),
#             algorithm=hashes.SHA256(),
#             label=None
#         )
#     )
#     return plaintext.decode()

# # Load the certificate
# cert = load_certificate()
# public_key = cert.public_key()

# # Load the private key from the file
# private_key = load_private_key() # Loading the private key from private_key.pem

# # Data to encrypt
# data = "This is some secret data."

# # Encrypt the data
# ciphertext = encrypt_data(data, public_key)
# print("Ciphertext:", ciphertext)

# # Decrypt the data (using the loaded private key)
# plaintext = decrypt_data(ciphertext, private_key)
# print("Plaintext:", plaintext)

# %% [markdown]
# ## How HTTPS Works
#
# **Explanation:**
#
# *   **Self-signed certificate:** The code generates a self-signed certificate for demonstration purposes.
# *   **Diffie-Hellman key exchange:** The client and server simulate a Diffie-Hellman key exchange to establish a shared secret key.
# *   **Symmetric encryption:** The shared key is then used with Fernet (symmetric encryption) to encrypt and decrypt a message.
#
# **Key Takeaways:**
#
# *   **Certificates for Authentication:**  While certificates themselves don't encrypt data, they play a crucial role in authenticating the server and establishing trust.
# *   **Key Exchange:**  Diffie-Hellman allows for secure key exchange, even over an insecure channel.
# *   **Symmetric Encryption for Data:**  Symmetric encryption is more efficient for encrypting larger amounts of data.
# *   **Real-World Applications:**  This is how HTTPS works, where certificates are used to verify websites and establish secure connections for data transfer.
#
# This example provides a hands-on demonstration of how certificates, combined with key exchange and symmetric encryption, enable secure communication. Remember to adapt and expand upon this example to fit your specific teaching goals and the level of your students.

# %%
# from cryptography import x509
# from cryptography.x509.oid import NameOID
# from cryptography.hazmat.backends import default_backend
# from cryptography.hazmat.primitives import hashes
# from cryptography.hazmat.primitives.asymmetric import rsa, padding
# from cryptography.hazmat.primitives import serialization
# from cryptography.hazmat.primitives.serialization import NoEncryption, Encoding, PrivateFormat
# import datetime

# def generate_private_key(filename="key.pem"):
#     """
#     Generates a private key and saves it to a file.
#     """
#     key = rsa.generate_private_key(
#         public_exponent=65537,
#         key_size=2048,
#         backend=default_backend()
#     )
#     with open(filename, "wb") as f:
#         f.write(key.private_bytes(
#             encoding=serialization.Encoding.PEM,
#             format=serialization.PrivateFormat.PKCS8,
#             encryption_algorithm=NoEncryption()
#         ))
#     return key

# def generate_self_signed_certificate(private_key, filename="certificate.pem"):
#     """
#     Generates a self-signed certificate.
#     """
#     subject = issuer = x509.Name([
#         x509.NameAttribute(NameOID.COUNTRY_NAME, u"US"),
#         x509.NameAttribute(NameOID.STATE_OR_PROVINCE_NAME, u"California"),
#         x509.NameAttribute(NameOID.LOCALITY_NAME, u"San Francisco"),
#         x509.NameAttribute(NameOID.ORGANIZATION_NAME, u"My Company"),
#         x509.NameAttribute(NameOID.COMMON_NAME, u"mysite.com"),
#     ])
#     cert = x509.CertificateBuilder().subject_name(
#         subject
#     ).issuer_name(
#         issuer
#     ).public_key(
#         private_key.public_key()
#     ).serial_number(
#         x509.random_serial_number()
#     ).not_valid_before(
#         datetime.datetime.utcnow()
#     ).not_valid_after(
#         datetime.datetime.utcnow() + datetime.timedelta(days=365)
#     ).add_extension(
#         x509.SubjectAlternativeName([x509.DNSName(u"mysite.com")]),
#         critical=False,
#     ).sign(private_key, hashes.SHA256(), default_backend())
#     with open(filename, "wb") as f:
#         f.write(cert.public_bytes(serialization.Encoding.PEM))
#     return cert

# def encrypt_data(data, public_key):
#     """
#     Encrypts data using the public key from the certificate.
#     """
#     ciphertext = public_key.encrypt(
#         data.encode(),
#         padding.OAEP(
#             mgf=padding.MGF1(algorithm=hashes.SHA256()),
#             algorithm=hashes.SHA256(),
#             label=None
#         )
#     )
#     return ciphertext

# def decrypt_data(ciphertext, private_key):
#     """
#     Decrypts data using the private key.
#     """
#     plaintext = private_key.decrypt(
#         ciphertext,
#         padding.OAEP(
#             mgf=padding.MGF1(algorithm=hashes.SHA256()),
#             algorithm=hashes.SHA256(),
#             label=None
#         )
#     )
#     return plaintext.decode()

# %%
# # Example: generate the private key and self-signed certificate

# %% [markdown]
# This code demonstrates the following:
#
# 1. **Generates a private key and a self-signed certificate:**
#    * `generate_private_key()` creates an RSA private key and saves it to `key.pem`.
#    * `generate_self_signed_certificate()` creates a self-signed certificate using the private key and saves it to `certificate.pem`.
#
# 2. **Encrypts and decrypts data:**
#    * `encrypt_data()` encrypts the data using the public key extracted from the certificate.
#    * `decrypt_data()` decrypts the ciphertext using the private key.
#
# 3. **Prints the ciphertext and plaintext:**
#    * The code prints the hexadecimal representation of the ciphertext and the decrypted plaintext.
#
# This example demonstrates how to use the generated private key and certificate for encryption and decryption, providing a visual representation of the process.

# %% [markdown]
# The private key and self-signed certificate have a close relationship and play distinct roles in secure communication:
#
# **Private Key**
#
# * **Secret Identity:** Think of the private key as your secret identity or a key to a safe. It's a unique and confidential piece of information that should never be shared with anyone.
# * **Mathematical Value:** It's a large, randomly generated number used for cryptographic operations.
# * **Core Functions:**
#     * **Decryption:**  It decrypts messages that were encrypted with the corresponding public key.
#     * **Digital Signatures:** It creates digital signatures to authenticate the sender of a message or document.
#
# **Self-Signed Certificate**
#
# * **Digital Passport:** Think of a self-signed certificate as a passport that you issue to yourself. It contains your identity information and your public key.
# * **Issued by You:**  You create and sign the certificate yourself using your private key.
# * **Limited Trust:** Since you're vouching for yourself, this certificate is not inherently trusted by others. It's like showing someone a homemade ID card – they might not accept it as proof of identity.
# * **Useful for Testing:** Self-signed certificates are mainly used for testing and development purposes where trust is not a major concern.
#
# **Relationship and Process**
#
# 1. **Generate Private Key:** You first generate a private key. This is a secret value that you keep confidential.
#
# 2. **Create Certificate Signing Request (CSR):**  You create a CSR, which includes your identity information (e.g., name, organization) and your public key (derived from your private key).
#
# 3. **Self-Sign the Certificate:** You use your private key to digitally sign the CSR, creating a self-signed certificate. This signature essentially says, "I vouch for the information in this certificate."
#
# 4. **Distribute Certificate:** You can share the self-signed certificate with others. However, they will need to manually trust the certificate since it wasn't issued by a trusted Certificate Authority (CA).
#
# **Analogy**
#
# Imagine you create a personal website and want to secure it with HTTPS. You generate a private key and use it to create a self-signed certificate. When someone visits your website, their browser will show a warning because it doesn't trust the self-signed certificate. However, if the visitor explicitly trusts your certificate, they can proceed with a secure connection.
#
# **Key Takeaways**
#
# * The private key is a secret value used for decryption and digital signatures.
# * A self-signed certificate is a certificate that you issue to yourself using your private key.
# * Self-signed certificates are primarily used for testing and development purposes.
# * In real-world scenarios, you would typically obtain a certificate from a trusted CA to establish trust with others.

# %% [markdown]
# ## Hashing
#
# **1. Simple Hashing: Length-Based Hashing**
#
#    * **Concept:**  This is a very basic (and not cryptographically secure) example.  The hash is simply the length of the input string.
#    * **Python Example:**

# %%
# Example

# %% [markdown]
# * **Explanation:**  As you can see, this is a very weak hash function, as many different inputs will produce the same hash (collision).
#
# **2.  Slightly More Complex:  Sum of ASCII Values**
#
#    * **Concept:**  This hash function calculates the sum of the ASCII values of the characters in the input string.
#    * **Python Example:**

# %%
# Example

# %% [markdown]
#    * **Explanation:** This is still a weak hash function, but it's slightly better than the length-based hash, as it takes the characters themselves into account. However, it's still prone to collisions (e.g., "ab" and "ba" would have the same hash).
#
# **3.  Getting More Secure:  MD5**
#
#    * **Concept:** MD5 (Message Digest Algorithm 5) is a widely known cryptographic hash function that produces a 128-bit hash value. While MD5 was once considered secure, it is now known to have vulnerabilities and is not recommended for new applications. However, it's still useful for educational purposes to demonstrate a real-world hash function.
#    * **Python Example:**

# %%
# Example

# %% [markdown]
#    * **Explanation:** MD5 uses a more complex algorithm involving bitwise operations, padding, and modular arithmetic to produce a hash that is much more resistant to collisions than the previous examples.
#
# **4. Modern and Secure: SHA-256**
#
#    * **Concept:** SHA-256 (Secure Hash Algorithm 256-bit) is a modern and widely used cryptographic hash function that produces a 256-bit hash value. It is considered secure and is used in various security applications, including digital signatures, SSL/TLS certificates, and password storage.
#    * **Python Example:**

# %%
# Example

# %% [markdown]
#    * **Explanation:** SHA-256 uses an even more complex algorithm than MD5, making it more resistant to collisions and attacks.
#
# **Key Takeaways for Students**
#
# * **Collision Resistance:** Emphasize the importance of collision resistance in cryptographic hash functions.
# * **One-Way Function:**  Explain that it should be computationally infeasible to reverse a hash to get the original input.
# * **Avalanche Effect:**  Even a small change in the input should result in a significantly different hash.
# * **Applications:**  Discuss the various applications of hash functions in security, such as data integrity, password storage, and digital signatures.
#
# This progression of examples, from simple to complex, helps illustrate the evolution of hashing algorithms and the increasing importance of security in modern applications.

# %% [markdown]
# ## HMAC
#
# HMAC (Hash-based Message Authentication Code) is a specific type of message authentication code (MAC) that involves a cryptographic hash function and a secret cryptographic key. It's used to verify both the *data integrity* and the *authenticity* of a message.
#
# **How HMAC works:**
#
# 1. **Keyed Hashing:** HMAC combines the message data with a secret key in a specific way before hashing it. This key is only known to the sender and the intended recipient(s).
#
# 2. **Cryptographic Hash Function:** A strong cryptographic hash function (like SHA-256) is applied to the combined key and message. This generates a unique "fingerprint" (the HMAC) for the message.
#
# 3. **Verification:** The recipient of the message performs the same HMAC calculation using the same key and compares the result to the HMAC received with the message. If they match, it means:
#    - The message has not been tampered with (integrity).
#    - The message came from the expected sender (authentication).
#
# **Why is HMAC important?**
#
# * **Data Integrity:**  HMAC helps ensure that the data you receive has not been altered or corrupted during transmission.
# * **Authentication:**  HMAC verifies that the message originated from the sender you expect and not an imposter.
# * **Security:**  Because the HMAC calculation involves a secret key, only someone with the key can generate a valid HMAC. This helps protect against unauthorized modification and forgery of messages.
#
# **Common Use Cases**
#
# * **API Authentication:** Many web APIs use HMAC for authentication. When a client sends a request to the API, it includes an HMAC of the request data calculated using its secret key. The API server, which also has the client's secret key, verifies the HMAC to authenticate the client.
# * **Message Signing:** HMAC can be used to digitally sign messages, ensuring that the sender cannot deny sending the message (non-repudiation).
# * **Network Protocols:**  HMAC is used in various network protocols like IPsec and TLS to protect the integrity and authenticity of data packets.
#
# **Key Takeaways**
#
# * HMAC is a way to ensure data integrity and authenticity using a combination of a secret key and a cryptographic hash function.
# * It's widely used in various security applications, including API authentication, message signing, and network security.
# * Understanding HMAC is crucial for building secure systems and protecting against unauthorized modification and forgery of data.

# %%
# import hmac
# import hashlib

# def generate_hmac(key, message):
#     """
#     Generates an HMAC using SHA-256.
#     """
#     # Ensure the key is bytes
#     if not isinstance(key, bytes):
#         key = key.encode()

#     # Create the HMAC object
#     hmac_obj = hmac.new(key, msg=message.encode(), digestmod=hashlib.sha256)

#     # Get the HMAC value as a hexadecimal string
#     hmac_value = hmac_obj.hexdigest()
#     return hmac_value

# %%
# Example usage

# %% [markdown]
# **Explanation**
#
# * `hmac.new()`: Creates a new HMAC object. You provide the key, the message, and the hash function to use (SHA-256 in this case).
# * `hmac_obj.hexdigest()`:  Returns the HMAC value as a hexadecimal string.
#
# **How HMAC Works**
#
# 1. **Keyed Hashing:** HMAC combines a secret key with the message in a specific way before hashing. This ensures that only someone with the key can generate a valid HMAC.
# 2. **Cryptographic Hash Function:** It uses a strong cryptographic hash function (like SHA-256) to generate the final HMAC.
# 3. **Integrity and Authentication:** HMAC provides both data integrity (ensuring the message hasn't been tampered with) and authentication (verifying that the message originated from the expected sender).
#
# **Key Concepts for Your Class**
#
# * **Message Authentication:** Explain how HMAC is used to verify the authenticity of messages.
# * **Data Integrity:** Discuss how HMAC ensures that data has not been modified in transit.
# * **Secret Key Protection:** Emphasize the importance of keeping the HMAC key secret and secure.
# * **Applications:** Explore real-world applications of HMAC, such as API authentication, message signing, and data integrity checks in network protocols.
#
# **Class Activity Ideas**
#
# * **HMAC Verification:** Have students write code to verify an HMAC value given a key and a message.
# * **API Authentication:** Simulate an API authentication scenario where clients use HMAC to authenticate their requests.
# * **Compare with Digital Signatures:** Discuss the similarities and differences between HMAC and digital signatures.
# * **Implement Different Hash Functions:** Explore how using different hash functions in HMAC affects the output.
#
# This example provides a basic understanding of how HMAC works. You can adapt and expand upon it to delve into more advanced concepts and real-world applications in your class.

# %% [markdown]
# ## Wireless
#
# **1. WPA2-PSK (Wi-Fi Protected Access 2 with Pre-Shared Key)**
#
# This is the most common encryption method used in home and small office Wi-Fi networks. It uses a pre-shared key (PSK) to encrypt communication between devices and the Wi-Fi router.
#
# * **Concept:** WPA2-PSK uses the Advanced Encryption Standard (AES) in Counter mode with Cipher Block Chaining Message Authentication Code Protocol (CCMP) for encryption and authentication.
# * **Code Example (Conceptual):**

# %%
# import hashlib
# from cryptography.hazmat.backends import default_backend
# from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes

# def generate_pmk(ssid, password):
#     """
#     Generates the Pairwise Master Key (PMK) from the SSID and password.
#     This is a simplified example; the actual PBKDF2 function is more complex.
#     """
#     return hashlib.pbkdf2_hmac('sha1', password.encode(), ssid.encode(), 4096, 32)

# def encrypt_data(data, pmk, packet_number):
#     """
#     Encrypts data using AES-CCMP.
#     This is a simplified example; the actual CCMP implementation is complex.
#     """
#     # --- Simplified CCMP Key Derivation ---
#     tk = hashlib.sha256(pmk + packet_number.to_bytes(2, 'big')).digest()[:16]  # 128-bit TK
#     mic_key = hashlib.sha256(pmk + b"MIC Key").digest()[:8]  # 64-bit MIC Key

#     # --- Simplified IV Generation ---
#     # IV should be 16 bytes (128 bits) for AES-CTR
#     iv = packet_number.to_bytes(2, 'big') + b'\x00' * 14  # Pad to 16 bytes

#     # --- AES Encryption ---
#     cipher = Cipher(algorithms.AES(tk), modes.CTR(iv), backend=default_backend())
#     encryptor = cipher.encryptor()
#     ciphertext = encryptor.update(data) + encryptor.finalize()

#     # --- Simplified MIC Calculation ---
#     mic = hashlib.sha1(mic_key + data).digest()[:8]  # 8-byte MIC

#     return ciphertext + mic  # Return ciphertext with MIC

# %%
# Example Usage (Conceptual)

# %% [markdown]
# * **Explanation:**
#     * `generate_pmk()`: Derives the PMK from the SSID and password using PBKDF2 (Password-Based Key Derivation Function 2).
#     * `encrypt_data()`: Encrypts the data using AES-CCMP. This involves key derivation, IV generation, encryption, and adding a Message Integrity Check (MIC) for authentication.
# * **Important Note:** Implementing the full WPA2-PSK protocol is complex and involves many details. This code example provides a high-level overview of the key concepts.

# %% [markdown]
# That's a mouthful, but it describes the core security features of WPA2-PSK, a common Wi-Fi encryption protocol. Let's break it down:
#
# * **WPA2-PSK:**  This stands for Wi-Fi Protected Access 2 with Pre-Shared Key. It's the security standard used by most Wi-Fi networks.
#     * **PSK (Pre-Shared Key):**  This is the password or passphrase you enter when connecting to a Wi-Fi network.
#
# * **AES (Advanced Encryption Standard):** This is a strong encryption algorithm that's widely used to protect data. Think of it as a powerful way to scramble information so that only someone with the key can unscramble it.
#
# * **Counter Mode (CTR):** This is a mode of operation for AES. It means that AES is used to encrypt a counter value, and the result is XORed with the plaintext to produce the ciphertext. This is efficient and secure for encrypting data streams.
#
# * **Cipher Block Chaining Message Authentication Code Protocol (CCMP):** This is a protocol that provides both encryption and authentication.
#     * **Encryption:**  Uses AES in Counter mode to encrypt the data.
#     * **Authentication:** Uses a Message Integrity Check (MIC) to ensure that the data hasn't been tampered with and that it came from the expected source. The MIC is like a digital signature for the data.
#
# **In simpler terms:**
#
# WPA2-PSK uses AES to scramble your Wi-Fi data, and CCMP ensures that the data is scrambled securely and hasn't been altered in transit.
#
# **Why is this important?**
#
# * **Confidentiality:**  Encryption ensures that only authorized devices (those with the correct password) can access your Wi-Fi data.
# * **Integrity:** CCMP's authentication mechanisms help prevent attackers from modifying or injecting malicious data into your Wi-Fi traffic.
#
# **Key takeaway:**
#
# WPA2-PSK with AES-CCMP provides a robust level of security for Wi-Fi networks, protecting your data from eavesdropping and tampering. However, it's important to use a strong and unique password (PSK) to make it difficult for attackers to crack your Wi-Fi encryption.

# %% [markdown]
# Counter mode (CTR) is a mode of operation for block ciphers like AES. It's a way to encrypt data that's more efficient and secure than some other modes, especially for encrypting data streams.
#
# Here's how it works:
#
# 1. **Counter Initialization:** A counter value is initialized. This counter is a unique value that changes for each block of data being encrypted.
#
# 2. **Encryption of Counter:** The block cipher (e.g., AES) encrypts the counter value using the secret key.
#
# 3. **XOR with Plaintext:** The encrypted counter value is XORed with the plaintext block to produce the ciphertext block.
#
# 4. **Counter Increment:** The counter is incremented for the next block, and the process repeats.
#
# **Key Features of CTR Mode**
#
# * **Stream Cipher:** CTR mode effectively turns a block cipher into a stream cipher. This means that each block of data is encrypted independently, making it suitable for encrypting continuous streams of data like video or audio.
#
# * **Efficiency:** CTR mode is very efficient because the encryption of the counter can be done in parallel for multiple blocks. This makes it faster than modes like CBC (Cipher Block Chaining), where each block depends on the previous one.
#
# * **Random Access:**  You can encrypt or decrypt any block in the data stream without having to process the previous blocks. This is useful for applications where random access to data is required.
#
# * **No Padding:** CTR mode doesn't require padding for data that's not a multiple of the block size because it operates on the data as a stream.
#
# **Advantages of CTR Mode**
#
# * **Efficiency:**  Parallel encryption of counter values makes it fast.
# * **Security:**  CTR mode is considered secure when used with a strong block cipher like AES.
# * **No Padding:**  Simplifies implementation and avoids potential padding-related vulnerabilities.
# * **Random Access:**  Allows for efficient encryption and decryption of data streams.
#
# **Applications of CTR Mode**
#
# * **Network Security:**  Used in protocols like IPsec and SSH to encrypt network traffic.
# * **Disk Encryption:**  Used to encrypt data on hard drives and SSDs.
# * **Secure Communication:**  Used in various secure communication protocols.
#
# **Key Takeaway**
#
# CTR mode is a versatile and efficient mode of operation for block ciphers, offering advantages in speed, security, and flexibility. It's a popular choice for encrypting data streams and in applications where random access to data is required.

# %% [markdown]
# **2. WPA3-SAE (Wi-Fi Protected Access 3 with Simultaneous Authentication of Equals)**
#
# This is the newer generation of Wi-Fi security that aims to improve upon WPA2-PSK. It uses SAE (Simultaneous Authentication of Equals) for stronger authentication and forward secrecy.
#
# * **Concept:** WPA3-SAE uses a more secure key establishment protocol based on elliptic curve cryptography.
# * **Important Note:** Implementing the full WPA3-SAE protocol is complex and involves many details. This code example provides a high-level overview of the key concepts.

# %% [markdown]
# **3. Bluetooth Low Energy (BLE) Security**
#
# BLE uses various security measures, including pairing and encryption, to protect communication.
#
# * **Concept:** BLE pairing involves exchanging keys and establishing an encrypted connection between devices.
# * **Explanation:**
#     * `encrypt_ble_data()`: Encrypts the data using AES-CCM, which provides both confidentiality and authentication.
# * **Important Note:** BLE security involves various modes and procedures. This code example provides a basic idea of how encryption is used in BLE.
#
# **Key Takeaways for Students**
#
# * **Wireless Security Importance:** Emphasize the importance of encryption in wireless communication to protect sensitive data.
# * **Different Standards:** Discuss different wireless security standards (WPA2, WPA3, BLE) and their security features.
# * **Real-World Applications:** Relate these concepts to everyday technologies like Wi-Fi, Bluetooth devices, and IoT (Internet of Things) security.
#
# Remember, these code examples are simplified representations. Implementing full wireless security protocols is complex and requires in-depth knowledge of the standards and cryptography. However, these examples can serve as a good starting point for engaging students and introducing them to the key concepts of wireless security.

# %% [markdown]
# ## Team Challenge
#
# * Break out into teams
# * Decrypt the secret message provided in class
# * Show your work in a Colab notebook
# * Let me know ASAP your solution to get the appropriate team points
