# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/INFO5737/blob/main/KDD99Cup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KDDCup 99
#
# * https://www.ecb.torontomu.ca/~bagheri/papers/cisda.pdf

# %%
# import numpy as np
# import pandas as pd

# from sklearn.datasets import fetch_kddcup99

# dataset = fetch_kddcup99()
# dataset

# %%
# get keys

# %%
# get description

# %%
# print feature and target names

# %%
# create housing dataframe
